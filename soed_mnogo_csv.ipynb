# %%
print("something")
# Out:
# something

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sb
import pandas as pd
import glob
import os

# %%
os.chdir('C:/users/acer/Documents/Python Scripts/SMARD/Markt/Großhandel LU DE/2019/01')

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
print(all_filenames)
# Out:
# ['Gro_handelspreise_201901010000_201901012359_1.csv', 'Gro_handelspreise_201901020000_201901022359_1.csv', 'Gro_handelspreise_201901030000_201901032359_1.csv', 'Gro_handelspreise_201901040000_201901042359_1.csv', 'Gro_handelspreise_201901050000_201901052359_1.csv', 'Gro_handelspreise_201901060000_201901062359_1.csv', 'Gro_handelspreise_201901070000_201901072359_1.csv', 'Gro_handelspreise_201901080000_201901082359_1.csv', 'Gro_handelspreise_201901090000_201901092359_1.csv', 'Gro_handelspreise_201901100000_201901102359_1.csv', 'Gro_handelspreise_201901110000_201901112359_1.csv', 'Gro_handelspreise_201901120000_201901122359_1.csv', 'Gro_handelspreise_201901130000_201901132359_1.csv', 'Gro_handelspreise_201901140000_201901142359_1.csv']

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f, sep=';', na_values='-', decimal=',') for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
print(combined_csv)
# Out:
#          Datum Uhrzeit  Deutschland/Luxemburg[Euro/MWh]  Dänemark 1[Euro/MWh]  \
# 0   01.01.2019   00:00                            28.32                 28.32
# 1   01.01.2019   01:00                            10.07                 10.07
# 2   01.01.2019   02:00                            -4.08                 -4.08
# 3   01.01.2019   03:00                            -9.91                 -9.91
# 4   01.01.2019   04:00                            -7.41                 -7.41
# ..         ...     ...                              ...                   ...
# 19  14.01.2019   19:00                            50.52                 50.52
# 20  14.01.2019   20:00                            49.61                 49.61
# 21  14.01.2019   21:00                            44.30                 44.30
# 22  14.01.2019   22:00                            41.29                 41.29
# 23  14.01.2019   23:00                            37.26                 37.26
#
# ...

# %%
type(all_filenames)
# Out:
# list

# %%
filenames1=all_filenames[2:5] #должны быть дни с 3 января по 5-е

# %%
combined_csv1 = pd.concat([pd.read_csv(f, sep=';', na_values='-', decimal=',') for f in filenames1 ])
combined_csv1.to_csv( "combined_csv1.csv", index=False, encoding='utf-8-sig')
print(combined_csv1)
# Out:
#          Datum Uhrzeit  Deutschland/Luxemburg[Euro/MWh]  Dänemark 1[Euro/MWh]  \
# 0   03.01.2019   00:00                            42.91                 42.91
# 1   03.01.2019   01:00                            45.22                 45.22
# 2   03.01.2019   02:00                            45.63                 48.31
# 3   03.01.2019   03:00                            44.00                 48.40
# 4   03.01.2019   04:00                            43.88                 48.79
# ..         ...     ...                              ...                   ...
# 19  05.01.2019   19:00                            59.44                 53.80
# 20  05.01.2019   20:00                            52.75                 52.75
# 21  05.01.2019   21:00                            51.90                 51.90
# 22  05.01.2019   22:00                            51.38                 51.38
# 23  05.01.2019   23:00                            49.96                 49.96
#
# ...

# %%
combined_csv1.columns=combined_csv1.columns.str.replace('[', '(').str.replace(']', ')') 
#не забыть поменять скобочки!

# %%
combined_csv1.plot(x='Uhrzeit', y=['Deutschland/Luxemburg(Euro/MWh)','Dänemark 1(Euro/MWh)'])
#график трёх дней!

# %%
combined_csv.columns=combined_csv.columns.str.replace('[', '(').str.replace(']', ')')

# %%
combined_csv.plot(x='Uhrzeit', y=['Deutschland/Luxemburg(Euro/MWh)','Dänemark 1(Euro/MWh)'])
#график всех дней из папки!
