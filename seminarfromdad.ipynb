# %%
import pandas as pd

# %%
df = pd.read_csv('daily/Gro_handelspreise_201901010000_201901012359_1.csv', sep=';', index_col=[0,1])

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sb

# %%
import numpy as np

df = df.replace({",":"."}, regex=True)
df = df.replace({"-":np.nan}, regex=True)


import numpy as np

#np.array(data)[0:2, 2:4].astype(np.float)

# %%
data2 = df.stack().reset_index().rename(columns={'level_2':'Country',0:'Price'})







data3=pd.DataFrame.from_dict(data2)


#data3.describe

data3.astype({'Price': 'float64'}).dtypes
data3 = data3.replace({":00":""}, regex=True)
data3.astype({'Uhrzeit': 'int32'}).dtypes


#print(data3)
# Out:
# Datum      object
# Uhrzeit     int32
# Country    object
# Price      object
# dtype: object

# %%
sb.set(style="ticks", color_codes=True)
sb.pairplot(data3.dropna(),hue="Country")
