# %%
import pandas as pd

# %%
data = pd.read_csv('daily/Gro_handelspreise_201901010000_201901012359_1.csv', sep=';')
print(data)
# Out:
#          Datum Uhrzeit Deutschland/Luxemburg[Euro/MWh] Dänemark 1[Euro/MWh]  \
# 0   01.01.2019   00:00                           28,32                28,32
# 1   01.01.2019   01:00                           10,07                10,07
# 2   01.01.2019   02:00                           -4,08                -4,08
# 3   01.01.2019   03:00                           -9,91                -9,91
# 4   01.01.2019   04:00                           -7,41                -7,41
# 5   01.01.2019   05:00                          -12,55               -12,55
# 6   01.01.2019   06:00                          -17,25               -17,25
# 7   01.01.2019   07:00                          -15,07               -15,07
# 8   01.01.2019   08:00                           -4,93                -4,93
# 9   01.01.2019   09:00                           -6,33                -6,33
# 10  01.01.2019   10:00                           -4,93                -4,93
# ...

# %%
data.head()
# Out:
#         Datum Uhrzeit Deutschland/Luxemburg[Euro/MWh] Dänemark 1[Euro/MWh]  \
# 0  01.01.2019   00:00                           28,32                28,32
# 1  01.01.2019   01:00                           10,07                10,07
# 2  01.01.2019   02:00                           -4,08                -4,08
# 3  01.01.2019   03:00                           -9,91                -9,91
# 4  01.01.2019   04:00                           -7,41                -7,41
#
#   Dänemark 2[Euro/MWh] Frankreich[Euro/MWh] Italien (Nord)[Euro/MWh]  \
# 0                28,32                   51                        -
# 1                10,07                46,27                        -
# 2                -4,08                39,78                        -
# 3                -9,91                27,87                        -
# 4                -7,41                23,21                        -
#
#   Niederlande[Euro/MWh] Polen[Euro/MWh] Schweden 4[Euro/MWh]  \
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(data["Datum"], data["Uhrzeit"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b72ec51a1d4d> in <module>
# ----> 1 sb.pairplot(data["Datum"], data["Uhrzeit"])
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2068         raise TypeError(
#    2069             "'data' must be pandas DataFrame object, not: {typefound}".format(
# -> 2070                 typefound=type(data)))
#    2071
#    2072     if plot_kws is None:
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'pandas.core.series.Series'>

# %%
data.describe()
# Out:
#              Datum Uhrzeit Deutschland/Luxemburg[Euro/MWh]  \
# count           24      24                              24
# unique           1      24                              23
# top     01.01.2019   19:00                           -4,93
# freq            24       1                               2
#
#        Dänemark 1[Euro/MWh] Dänemark 2[Euro/MWh] Frankreich[Euro/MWh]  \
# count                    24                   24                   24
# unique                   23                   23                   23
# top                   -4,93                -4,93                   25
# freq                      2                    2                    2
#
#        Italien (Nord)[Euro/MWh] Niederlande[Euro/MWh] Polen[Euro/MWh]  \
# count                        24                    24              24
# unique                        1                    24               1
# top                           -                 49,92               -
# ...

# %%
sb.pairplot(data.dropna())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-72260615f7f8> in <module>
# ----> 1 sb.pairplot(data.dropna())
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
#    2086     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, height, aspect, despine, dropna, size)
#    1279
#    1280         # Label the axes
# ...

# %%
data
# Out:
#          Datum Uhrzeit Deutschland/Luxemburg[Euro/MWh] Dänemark 1[Euro/MWh]  \
# 0   01.01.2019   00:00                           28,32                28,32
# 1   01.01.2019   01:00                           10,07                10,07
# 2   01.01.2019   02:00                           -4,08                -4,08
# 3   01.01.2019   03:00                           -9,91                -9,91
# 4   01.01.2019   04:00                           -7,41                -7,41
# 5   01.01.2019   05:00                          -12,55               -12,55
# 6   01.01.2019   06:00                          -17,25               -17,25
# 7   01.01.2019   07:00                          -15,07               -15,07
# 8   01.01.2019   08:00                           -4,93                -4,93
# 9   01.01.2019   09:00                           -6,33                -6,33
# 10  01.01.2019   10:00                           -4,93                -4,93
# ...

# %%
data["Datum"][7]
# Out:
# '01.01.2019'

# %%
data[1:3, :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-61ced84c2e82> in <module>
# ----> 1 data[1:3, :]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
import numpy as np
np.array(data)[0:2, 2:4].astype(np.float, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-85266a355c4f> in <module>
#       1 import numpy as np
# ----> 2 np.array(data)[0:2, 2:4].astype(np.float, delimiter=",")
#
# TypeError: 'delimiter' is an invalid keyword argument for astype()
